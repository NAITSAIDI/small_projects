# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
website = 'https://www.cars.com/shopping/results/?stock_type=cpo&makes%5B%5D=mercedes_benz&models%5B%5D&list_price_max&maximum_distance=all&zip'

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="ep-theme-cars" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title data-suffix=" | Cars.com">Certified Used Mercedes-Benz for Sale | Cars.com</title>
# <meta content="Shop Mercedes-Benz vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 3,555 Mercedes-Benz models nationwide." name="description"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="Certified Used Mercedes-Benz for Sale | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/shopping/results" property="og:url"/>
# <meta content="Shop Mercedes-Benz vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 3,555 Mercedes-Benz models nationwide." property="og:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" property="og:image"/>
# <meta content="290349283473" property="fb:app_id"/>
# <meta content="app-id=353263352" name="apple-itunes-app"/>
# <meta content="@carsdotcom" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Certified Used Mercedes-Benz for Sale | Cars.com" name="twitter:title"/>
# <meta content="Shop Mercedes-Benz vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 3,555 Mercedes-Benz models nationwide." name="twitter:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" name="twitter:image"/>
# <script type="application/ld+json">{"@context":"http://www.schema.org","@type":"WebSite","name":"Cars.com","url":"https://www.cars.com/"}</script>
# <style>
# a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,button,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,main,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{border:0;font-weight:400;margin:0;padding:0;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block}body{line-height:1}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}table{border-collapse:collapse;border-spacing:0}.sds-checkbox,.sds-radio{display:inline;position:relative}.sds-checkbox:after,.sds-radio:after{content:"\a";white-space:pre}.sds-checkbox+.sds-checkbox,.sds-checkbox+.sds-radio,.sds-radio+.sds-checkbox,.sds-radio+.sds-radio{margin-top:16px}.sds-checkbox .sds-input,.sds-radio .sds-input{height:20px;left:0;opacity:0;position:absolute;top:0;width:20px}.sds-checkbox .sds-input+.sds-label,.sds-checkbox .sds-input+.sds-legend,.sds-radio .sds-input+.sds-label,.sds-radio .sds-input+.sds-legend{-webkit-user-select:none;-moz-user-select:none;user-select:none}.sds-checkbox .sds-input+.sds-label:before,.sds-checkbox .sds-input+.sds-legend:before,.sds-radio .sds-input+.sds-label:before,.sds-radio .sds-input+.sds-legend:before{border:1px solid #bdbdbd;content:"";height:20px;left:0;position:absolute;top:-.1em;width:20px}.sds-checkbox .sds-input:disabled+.sds-label,.sds-checkbox .sds-input:disabled+.sds-legend,.sds-radio .sds-input:disabled+.sds-label,.sds-radio .sds-input:disabled+.sds-legend{cursor:not-allowed;opacity:.4}.sds-checkbox .sds-input.error+.sds-label:before,.sds-checkbox .sds-input.error+.sds-legend:before,.sds-radio .sds-input.error+.sds-label:before,.sds-radio .sds-input.error+.sds-legend:before{border-color:#c10}.sds-checkbox .sds-input:focus+.sds-label:before,.sds-checkbox .sds-input:focus+.sds-legend:before,.sds-radio .sds-input:focus+.sds-label:before,.sds-radio .sds-input:focus+.sds-legend:before{box-shadow:0 0 0 2px #00bfde}.sds-checkbox .sds-input+.sds-label:after,.sds-checkbox .sds-input+.sds-legend:after,.sds-radio .sds-input+.sds-label:after,.sds-radio .sds-input+.sds-legend:after{border:3px solid #000;border-left:0;border-top:0;content:"";height:12px;left:7px;opacity:0;position:absolute;top:1px;transform:rotate(45deg);width:7px}.sds-inverse .sds-checkbox .sds-input+.sds-label:after,.sds-inverse .sds-checkbox .sds-input+.sds-legend:after,.sds-inverse .sds-radio .sds-input+.sds-label:after,.sds-inverse .sds-radio .sds-input+.sds-legend:after{border-color:#fff}.sds-checkbox .sds-input:checked+.sds-label:after,.sds-checkbox .sds-input:checked+.sds-legend:after,.sds-radio .sds-input:checked+.sds-label:after,.sds-radio .sds-input:checked+.sds-legend:after{opacity:1}.sds-checkbox .sds-label,.sds-checkbox .sds-legend,.sds-radio .sds-label,.sds-radio .sds-legend{cursor:pointer;margin:0;padding:0 0 0 32px;position:relative}.sds-checkbox .error~.sds-label,.sds-checkbox .error~.sds-legend,.sds-radio .error~.sds-label,.sds-radio .error~.sds-legend{color:#c10}.sds-checkbox:focus,.sds-radio:focus{outline:2px solid Highlight}@media(-webkit-min-device-pixel-ratio:0){.sds-checkbox:focus,.sds-radio:focus{outline-color:-webkit-focus-ring-color;outline-style:auto}}.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{max-width:1170px}@media (min-width:768px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{margin:0 auto}}@media (min-width:980px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{display:grid}}html{box-sizing:border-box;height:100%;width:100%}*,:after,:before{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;box-sizing: ...
#
#       </style>
# <style>
# .accordion-group{border-bottom:1px solid #e6e6e6}.accordion-header{align-items:center;display:flex;height:48px;justify-content:space-between;min-height:48px}.accordion-header .accordion-section-title{font-size:16px;width:100%}.accordion-header[aria-expanded=true] .accordion-section-icon{transform:rotate(180deg)}.accordion-panel[aria-hidden=true]{display:none}.accordion-panel[aria-hidden=false]{display:flex;flex-direction:column;padding:0 0 16px}.active-filter-tags{margin:0 16px 16px;position:relative}@media (min-width:768px){.active-filter-tags{margin-right:0}}.active-filter-tags .flex-container{display:flex;flex-direction:row;justify-content:space-between}.active-filter-tags .flex-container .show-more-less{align-content:flex-end;display:flex;flex-direction:row;justify-content:flex-start;margin-top:16px}.active-filter-tags .flex-container .show-more-less .sds-text-field__icon{stroke:#b0c!important;margin-left:5px;margin-top:5px}.active-filter-tags .flex-container .show-more-less span{color:#b0c;cursor:pointer}.active-filter-tags .flex-container .clear-all-filter-tags{margin-right:16px;margin-top:16px}.active-filter-tags .flex-container .clear-all-filter-tags span{color:#b0c;cursor:pointer}.active-filter-tags .active-filter-checkbox{display:none}.active-filter-tags .mobile-filtering-by{margin-bottom:16px}@media (min-width:768px){.active-filter-tags .mobile-filtering-by{display:none}}.branded-canvas{border:1px solid #e6e6e6;box-shadow:inset 0 -1px 0 0 #e6e6e6;height:520px;margin-bottom:24px;position:relative;width:100%}@media (min-width:768px){.branded-canvas{height:343px}}@media (min-width:980px){.branded-canvas{height:343px}}.branded-canvas .branded-canvas-main-container{display:flex;flex-direction:column;height:272px;overflow:hidden;position:relative;width:100%}@media (min-width:768px){.branded-canvas .branded-canvas-main-container{flex-direction:row;height:265px;justify-content:space-between}}.branded-canvas .branded-canvas-main-container .branded-canvas-from{color:#fff;font-size:11px;font-style:italic;left:10px;position:absolute;top:32px;z-index:1}.branded-canvas .branded-canvas-main-container .branded-canvas-logo{height:55px;position:absolute;right:12px;top:10px;width:55px;z-index:1}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{flex:0 0 45%;height:175px;position:relative;text-align:center;z-index:1}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{flex:0 0 50%}}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{max-width:280px;padding-top:52px;position:inherit}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{left:11%;max-width:80%;padding-top:0;position:absolute;top:30%}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:none}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:flex;justify-content:flex-end}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .sds-button--secondary-dense .sds-text-field__icon_1{stroke:#532380}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .sds-button--secondary-dense:hover .sds-text-field__icon_1{stroke:#fff;transition:stroke .25s ease}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1{flex:1 1 50%;margin:16px 8px 16px 0;padding:8px;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1 .sds-text-field__icon{stroke:#532380;margin-left:4px}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2{flex:1 1 50%;margin:16px 16px 16px 0;padding:8px;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2 .sds-text-field__icon{stroke:#fff;margin-left:4px} ...
#
#           </style>
# <script defer="" src="/e2aa3c3fdde1c44fd867/js/app.js?vsn=d"></script>
# <script id="datadog-config" type="application/json">
#     {
#         "clientToken": "pubd9e029f457b6d51b3d399c5b5c8fa7a4",
#         "applicationId": "c7070c7e-6068-4c84-828a-0e3b134e372d",
#         "site": "datadoghq.com",
#         "service": "cars_web",
#         "sampleRate": 2,
#         "trackInteractions": true,
#         "trackFrustrations": true
#
#     }
# </script>
# <script id="datadog-global-context" type="application/json">
# {"env":"production","trip_id":""}
# </script>
# <meta content="ciYnAz8QAiNQJDEcQxF9KTMLPigALAMh1qIiJYMLgsPS6h3aZiTKFuDt" name="csrf-token"/>
# </head>
# <div hidden="">
# <span id="new-tab-link">Opens website in a new tab</span>
# </div>
# <body>
# <div class="global-header-container">
# <cars-global-header>
# <header class="global-header">
# <section class="container">
# <a class="header-logo" data-activity-rule-type="page-over-page" data-component="header-click" data-linkname="header-home" href="/"><img alt="Cars.com" class="header-logo header-logo__img" src="/images/logo_cars-46214ae902ff93ba8fa2e40fb73dfa02.png?vsn=d"/></a>
# <nav class="">
# <ul class="header-links">
# <li class="header-link"><a class="link-active" data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">Cars for Sale</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">Research &amp; Reviews</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">News &amp; Videos</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell-your-car" data-nav-link="" href="/sell/">Sell Your Car</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">Service &amp; Repair</a></li>
# </ul>
# <button aria-haspopup="true" aria-label="navigation menu" class="nav-user-menu-button" data-activity-rule-type="custom" data-linkname="header-menu">
# <ep-svg class="menu-icon" library="cars" name="hamburger"></ep-svg>
# <span class="nav-user-name">
# Menu
#             </span>
# <span class="menu-text">Menu</span>
# </button>
# <div id="google-one-tap">
# <div data-client_id="67273791563-90cd8jqav0pgefmmb4l5732bguvbjapi.apps.googleusercontent.com" data-login_uri="/signin/google_callback/" data-moment_callback="trackGoogleOneTap" data-redirect_path="/shopping/results/?redirect_event%5Bsocial_platform%5D=google" id="g_id_onload">
# </div>
# </div>
# </nav>
# <ep-modal class="nav-modal">
# <div class="sds-heading--2" id="menu-heading">
# <span class="nav-user-name">
# Menu
#               </span>
# <span class="menu-text">Menu</span>
# </div>
# <ul class="menu-links">
# <li class="header-link"><a class="link-active" data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">Cars for Sale</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">Research &amp; Reviews</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">News &amp; Videos</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell-your-car" data-nav-link="" href="/sell/">Sell Your Car</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">Service &amp; Repair</a></li>
# </ul>
# <ul class="profile-links">
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-saved-cars" data-profile-link="" href="/profile/saved-cars/"><ep-svg library="cars" name="heart-empty"></ep-svg>
# Saved Cars</a></li>
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-saved-searches" data-profile-link="" href="/profile/saved-searches/"><ep-svg library="cars" name="search"></ep-svg>
# Saved Searches</a></li>
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-your-garage" data-profile-link="" href="/profile/your-garage/"><ep-svg library="cars" name="tag"></ep-svg>
# Your Garage</a></li>
# </ul>
# <div class="sign-in-up-out">
# <a class="header-signin sds-button--secondary-dense" content="Sign in" data-activity-rule-type="page-over-page" data-component="sign-in-start" data-linkname="header-sign-in" href="/signin/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3Dall%26models%255B%255D%3D%26stock_type%3Dcpo%26zip%3D">Sign in</a>
# <a class="header-signup sds-button--dense" content="Create an account" data-activity-rule-type="page-over-page" data-component="sign-up-start" data-linkname="header-sign-up" href="/signup/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3Dall%26models%255B%255D%3D%26stock_type%3Dcpo%26zip%3D">Create an account</a>
# </div>
# </ep-modal>
# </section>
# </header>
# </cars-global-header>
# </div>
# <section class="sds-page-container" role="main">
# <div data-qa="notifications-are-here"></div>
# <div data-phx-main="true" data-phx-session="SFMyNTY....._0wOlu-hKF0yEKLV5jYvqU3U8HCYRjVsLoscSlW3yMU" data-phx-static="SFMyNTY.g2gDaAJhBXQAAAADZAAKYXNzaWduX25ld2wAAAACZAANaXNfc2VhcmNoX2JvdGQADGN1cnJlbnRfdXNlcmpkAAVmbGFzaHQAAAAAZAACaWRtAAAAFHBoeC1GeHBIdlIwbGpRZWxucmZqbgYACSsomYMBYgABUYA.CBcsDxIlo7Az2_sAyINvkGwV79ZZps2bf9x6UWlFTCo" id="phx-FxpHvR0ljQelnrfj">
# <link as="image" href="https://platform.cstatic-images.com/large/in/v2/bf0fc2f2-1f67-52a0-8c51-a3fb7e05273a/36f4b5fa-9f94-42f6-a614-294e03fe0fbe/rA7Twsz4k4bPjOX42iGZmTRJiDU.jpg" rel="preload"/>
# <div aria-modal="true" class="sds-modal aria-modal sds-modal-one lead-form-container" id="srp-lead-form-modal" phx-hook="LeadForm" phx-target="#srp-lead-form-modal">
# <div class="lead-modal sds-modal__content" phx-click="close" phx-target="#srp-lead-form-modal" phx-value-close="false">
# <div class="lead-modal sds-modal__content-head">
# <div class="sds-icon--target btn-close" phx-click="reset" phx-target="#srp-lead-form-modal" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <div class="lead-modal sds-modal__content-body">
# <div class="dealer-section lead-form-top-anchor" id="dealer-section--">
# <header>
# <h2 class="sds-heading--3 lead-form-heading">Contact seller</h2>
# </header>
# </div>
# <div class="lead-form" id="lead-form-container-">
# <form action="#" data-index="" data-reset-activity-limit-for="email-lead-error--inline" id="fields-srp-lead-form-modal" method="post" phx-change="change" phx-hook="EmailLeadForm" phx-submit="save_lead" phx-target="#srp-lead-form-modal"><input name="_csrf_token" type="hidden" value="ciYnAz8QAiNQJDEcQxF9KTMLPigALAMh1qIiJYMLgsPS6h3aZiTKFuDt"/>
# <section data-activity-limit="1" data-activity-rule-type="custom" data-conversion-type="email-lead-error--inline" data-errorname="email-lead-error--inline" data-index="">
# <div>
# <div class="sds-field-group">
# <div class="customer-form">
# <div class="first-name">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="first_name-modal-" name="lead[first_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="first_name-modal-">First name</label>
# </div>
# </div>
# <div class="last-name">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="last_name-modal-" name="lead[last_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="last_name-modal-">Last name</label>
# </div>
# </div>
# <div class="email">
# <div class="sds-input-container">
# <input class="sds-text-field" data-emailtype="transact" data-fs="exclude" id="email-modal-" name="lead[email]" phx-debounce="blur" phx-hook="EmailInput" placeholder=" " type="text"/>
# <label class="sds-label" for="email-modal-">Email</label>
# </div>
# </div>
# <div class="phone">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="phone-modal-" name="lead[phone]" phx-debounce="blur" phx-hook="PhoneNumber" placeholder=" " type="tel"/>
# <label class="sds-label" for="phone-modal-">Phone (optional)</label>
# </div>
# </div>
# <input id="subject-modal-" name="lead[subject]" type="hidden" value="Ask a question"/>
# <div class="comments">
# <div class="sds-input-container sds-input-container--textarea">
# <textarea class="sds-text-field comment-box" data-fs="exclude" id="comments-modal-" name="lead[comments]" phx-debounce="blur" placeholder=" ">
# </textarea>
# <label class="sds-label" for="comments-modal-">Comments</label>
# </div>
# </div>
# </div>
# <div class="sds-field trade-in hidden">
# <div class="sds-field trade-in-checkbox">
# <div class="sds-checkbox trade-in" phx-click="show_trade_in" phx-target="#srp-lead-form-modal">
# <input class="sds-input" id="trade-in-checkbox-srp-lead-form-modal" type="checkbox"/>
# <label class="sds-label" for="trade-in-checkbox-srp-lead-form-modal">I have a trade in</label>
# </div>
# </div>
# <div class="sds-field-group trade-in-form hidden">
# <div class="make">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" id="fields-srp-lead-form-modal_make_select-modal-" name="lead[trade_in][make]"><optgroup label=""><option selected="" value="">Choose a make</option><option value="ac">AC</option><option value="acura">Acura</option><option value="alfa_romeo">Alfa Romeo</option><option value="american_motors">American Motors</option><option value="am_general">Am General</option><option value="aston_martin">Aston Martin</option><option value="auburn">Auburn</option><option value="audi">Audi</option><option value="austin">Austin</option><option value="austin_healey">Austin-Healey</option><option value="avanti_motors">Avanti Motors</option><option value="bentley">Bentley</option><option value="bmw">BMW</option><option value="bricklin">Bricklin</option><option value="bugatti">Bugatti</option><option value="buick">Buick</option><option value="cadillac">Cadillac</option><option value="checker">Checker</option><option value="chevrolet">Chevrolet</option><option value="chrysler">Chrysler</option><option value="citroen">Citroen</option><option value="daewoo">Daewoo</option><option value="daihatsu">Daihatsu</option><option value="datsun">Datsun</option><option value="delahaye">Delahaye</option><option value="delorean">Delorean</option><option value="desoto">Desoto</option><option value="detomaso">DeTomaso</option><option value="dodge">Dodge</option><option value="eagle">Eagle</option><option value="edsel">Edsel</option><option value="essex">Essex</option><option value="ferrari">Ferrari</option><option value="fiat">FIAT</option><option value="fisker">Fisker</option><option value="ford">Ford</option><option value="franklin">Franklin</option><option value="genesis">Genesis</option><option value="geo">Geo</option><option value="gmc">GMC</option><option value="honda">Honda</option><option value="hudson">Hudson</option><option value="hummer">Hummer</option><option value="hupmobile">Hupmobile</option><option value="hyundai">Hyundai</option><option value="infiniti">INFINITI</option><option value="international">International</option><option value="isuzu">Isuzu</option><option value="jaguar">Jaguar</option><option value="jeep">Jeep</option><option value="jensen">Jensen</option><option value="kaiser">Kaiser</option><option value="karma">Karma</option><option value="kia">Kia</option><option value="koenigsegg">Koenigsegg</option><option value="lamborghini">Lamborghini</option><option value="lancia">Lancia</option><option value="land_rover">Land Rover</option><option value="lasalle">LaSalle</option><option value="lexus">Lexus</option><option value="lincoln">Lincoln</option><option value="lotus">Lotus</option><option value="lucid">Lucid</option><option value="maserati">Maserati</option><option value="maybach">Maybach</option><option value="mazda">Mazda</option><option value="mclaren">McLaren</option><option value="mercedes_benz">Mercedes-Benz</option><option value="mercury">Mercury</option><option value="merkur">Merkur</option><option value="mg">MG</option><option value="mini">MINI</option><option value="mitsubishi">Mitsubishi</option><option value="morgan">Morgan</option><option value="morris">Morris</option><option value="nash">Nash</option><option value="nissan">Nissan</option><option value="oldsmobile">Oldsmobile</option><option value="opel">Opel</option><option value="packard">Packard</option><option value="pagani">Pagani</option><option value="panoz">Panoz</option><option value="peugeot">Peugeot</option><option value="plymouth">Plymouth</option><option value="polestar">Polestar</option><option value="pontiac">Pontiac</option><option value="porsche">Porsche</option><option value="qvale">Qvale</option><option value="ram">RAM</option><option value="renault">Renault</option><option value="rivian">Rivian</option><option value="rolls_royce">Rolls-Royce</option><option value="rover">Rover</option><option value="saab">Saab</option><option value="saleen">Saleen</option><option value="saturn">Saturn</option><option value="scion">Scion</optio ...
# <label class="sds-label" for="make_select-modal-">Make</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="model">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-srp-lead-form-modal_model_select-modal-" name="lead[trade_in][model]"><optgroup label=""><option selected="" value="">Choose a model</option></optgroup></select>
# <label class="sds-label" for="model_select-modal-">Model</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="year">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-srp-lead-form-modal_year_select-modal-" name="lead[trade_in][year]"><optgroup label=""><option selected="" value="">Choose a year</option></optgroup></select>
# <label class="sds-label" for="year_select-modal-">Year</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="color">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="color-modal-" name="lead[trade_in][color]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="color-modal-">Exterior color</label>
# </div>
# </div>
# <div class="mileage">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="mileage_string-modal-" name="lead[trade_in][mileage_string]" phx-debounce="blur" phx-hook="Mileage" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="mileage_string-modal-">Mileage</label>
# </div>
# </div>
# <div class="vin">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="vin-modal-" name="lead[trade_in][vin]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="vin-modal-">VIN (optional)</label>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="sds-field sds-form-module__button">
# <button class="sds-button--fluid" type="submit">Contact seller</button>
# </div>
# <small class="sds-disclaimer">
# <p>
#
# By clicking here, you authorize Cars.com and its sellers/partners to contact you by text/calls which may include marketing and be by autodialer. Calls may be prerecorded. You also agree to our Privacy Statement. Consent is not required to purchase goods/services.
#
#         </p>
# <p>
# We value your privacy.
# <a data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Cars.com Privacy Statement</a>
# </p>
# </small>
# </div>
# </section>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div data-override-payload="null" phx-hook="LeadSubmissionTracker" phx-target="#srp-lead-form-modal" phx_value_cid="srp-lead-form-modal"></div>
# <div phx-hook="LeadFormPositionAdjustments"></div>
# <div id="auth-completion-listener" phx-hook="AuthCompletionListener"></div>
# <div aria-modal="true" class="sds-modal aria-modal sds-modal-one" data-activity-rule-type="custom" data-analytics-linkname="profiles-modal-close" data-component="profiles-modal" data-hook-callback="close_modal" id="auth-modal" phx-hook="ModalBackdrop" phx-target="#auth-modal">
# <div class="sds-modal__content">
# <div class="sds-modal__content-head">
# <div class="sds-icon--target btn-close" data-activity-rule-type="custom" data-component="profiles-modal" data-linkname="profiles-modal-close" phx-click="close_modal" phx-target="#auth-modal" role="button">
# <span class="sds-icon">
# <svg height="24" width="24"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <div class="sds-modal__content-body">
# <div class="sign-up">
# <h3 class="sds-heading--3 sds-heading--display sds-page-section__title">Create your account</h3>
# <div class="modal-body">
# <p class="sds-page-section__title--sub">
# Sign up access your saved searches anywhere, anytime, and from any device.
#     </p>
# <p class="sds-page-section__title--sub">
# Already have a profile? <a data-activity-rule-type="custom" data-component="profiles-modal" data-linkname="modal-sign-in" href="#" phx-click="sign_in" phx-target="#auth-modal">Sign in</a>.
#     </p>
# <ul class="sds-list social-link-list">
# <li class="social-link">
# <a class="sds-button facebook-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-facebook" href="/signin/fb_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3Dall%26models%255B%255D%3D%26redirect_event%255Bevent%255D%3Dsave_search%26redirect_event%255Bname%255D%3Dsearch_live%26redirect_event%255Bsocial_platform%255D%3Dfacebook%26stock_type%3Dcpo%26zip%3D">
# <svg class="facebook-svg-icon" height="1365.12" viewbox="0 0 14222 14222" width="1365.12" xmlns="http://www.w3.org/2000/svg">
# <circle cx="7111" cy="7112" fill="#fff" r="7111"></circle>
# <path d="M9879 9168l315-2056H8222V5778c0-562 275-1111 1159-1111h897V2917s-814-139-1592-139c-1624 0-2686 984-2686 2767v1567H4194v2056h1806v4969c362 57 733 86 1111 86s749-30 1111-86V9168z" fill="#1977f3"></path>
# </svg>
#   Sign in with Facebook
# </a>
# </li>
# <li class="social-link">
# <a class="sds-button google-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-google" href="/signin/google_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3Dall%26models%255B%255D%3D%26redirect_event%255Bevent%255D%3Dsave_search%26redirect_event%255Bname%255D%3Dsearch_live%26redirect_event%255Bsocial_platform%255D%3Dgoogle%26stock_type%3Dcpo%26zip%3D">
# <svg fill="none" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M28.48 16.2955C28.48 15.3736 28.3973 14.4873 28.2436 13.6364H16V18.665H22.9964C22.695 20.29 21.7791 21.6668 20.4023 22.5886V25.8505H24.6036C27.0618 23.5873 28.48 20.2545 28.48 16.2955Z" fill="#4285F4" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M16 29C19.51 29 22.4527 27.8359 24.6036 25.8505L20.4023 22.5886C19.2382 23.3686 17.7491 23.8295 16 23.8295C12.6141 23.8295 9.74819 21.5427 8.72592 18.47H4.38274V21.8382C6.52183 26.0868 10.9182 29 16 29Z" fill="#34A853" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M8.72591 18.47C8.46591 17.69 8.31818 16.8568 8.31818 16C8.31818 15.1432 8.46591 14.31 8.72591 13.53V10.1618H4.38273C3.50227 11.9168 3 13.9023 3 16C3 18.0977 3.50227 20.0832 4.38273 21.8382L8.72591 18.47Z" fill="#FBBC05" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M16 8.17045C17.9086 8.17045 19.6223 8.82636 20.9696 10.1145L24.6982 6.38591C22.4468 4.28818 19.5041 3 16 3C10.9182 3 6.52183 5.91318 4.38274 10.1618L8.72592 13.53C9.74819 10.4573 12.6141 8.17045 16 8.17045Z" fill="#EA4335" fill-rule="evenodd"></path>
# </svg>
#   Sign in with Google
# </a>
# </li>
# <li class="social-link">
# <a class="sds-button apple-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-google" href="/signin/apple_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dmercedes_benz%26maximum_distance%3Dall%26models%255B%255D%3D%26redirect_event%255Bevent%255D%3Dsave_search%26redirect_event%255Bname%255D%3Dsearch_live%26redirect_event%255Bsocial_platform%255D%3Dapple%26stock_type%3Dcpo%26zip%3D">
# <svg height="44px" version="1.1" viewbox="0 0 31 44" width="28px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>Apple logo</title>
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <path d="M15.7099491,14.8846154 C16.5675461,14.8846154 17.642562,14.3048315 18.28274,13.5317864 C18.8625238,12.8312142 19.2852829,11.852829 19.2852829,10.8744437 C19.2852829,10.7415766 19.2732041,10.6087095 19.2490464,10.5 C18.2948188,10.5362365 17.1473299,11.140178 16.4588366,11.9494596 C15.9152893,12.56548 15.4200572,13.5317864 15.4200572,14.5222505 C15.4200572,14.6671964 15.4442149,14.8121424 15.4562937,14.8604577 C15.5166879,14.8725366 15.6133185,14.8846154 15.7099491,14.8846154 Z M12.6902416,29.5 C13.8618881,29.5 14.3812778,28.714876 15.8428163,28.714876 C17.3285124,28.714876 17.6546408,29.4758423 18.9591545,29.4758423 C20.2395105,29.4758423 21.0971074,28.292117 21.9063891,27.1325493 C22.8123013,25.8038779 23.1867451,24.4993643 23.2109027,24.4389701 C23.1263509,24.4148125 20.6743484,23.4122695 20.6743484,20.5979021 C20.6743484,18.1579784 22.6069612,17.0588048 22.7156707,16.974253 C21.4353147,15.1382708 19.490623,15.0899555 18.9591545,15.0899555 C17.5217737,15.0899555 16.3501271,15.9596313 15.6133185,15.9596313 C14.8161157,15.9596313 13.7652575,15.1382708 12.521138,15.1382708 C10.1536872,15.1382708 7.75,17.0950413 7.75,20.7911634 C7.75,23.0861411 8.64383344,25.513986 9.74300699,27.0842339 C10.6851558,28.4129053 11.5065162,29.5 12.6902416,29.5 Z" fill="#FFFFFF" fill-rule="nonzero" id=""></path>
# </g>
# </svg>
#   Sign in with Apple
# </a>
# </li>
# </ul>
# <div class="separator-wrapper">
# <div class="sds-separator"></div>
# <div class="separator-text">Or</div>
# <div class="sds-separator"></div>
# </div>
# <form action="#" method="post" phx-submit="sign_up_continue" phx-target="#auth-modal"><input name="_csrf_token" type="hidden" value="ciYnAz8QAiNQJDEcQxF9KTMLPigALAMh1qIiJYMLgsPS6h3aZiTKFuDt"/>
# <div class="sds-field-group">
# <div class="sds-field email">
# <div class="sds-input-container">
# <input class="sds-text-field" data-emailtype="account" id="user_email" maxlength="255" name="user[email]" phx-hook="EmailInput" placeholder=" " type="text"/>
# <label class="sds-label" for="user_email">Email</label>
# </div>
# </div>
# </div>
# <div class="actions">
# <div class="sds-field">
# <button class="sds-button" type="submit">Continue</button>
# </div>
# </div>
# </form>
# <div class="disclaimer">
# <div class="sds-disclaimer">
# By signing up, you agree to our
# <a data-activity-rule-type="custom" data-component="privacy-statement" data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Privacy Statement</a>
# and
# <a data-activity-rule-type="custom" data-component="terms-of-service" data-linkname="tos" href="/about/terms/" target="_blank">Terms of Service</a>.
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="sds-page-section listings-page" data-applied-filter-criteria="" data-liveview-pageview="true" data-props='{"selected_refinement":null}' data-search-instance-id="0d1b54af-3b12-4e01-9020-12a254dfc64d" data-search-type="general-inventory-search" data-site-activity='{"resultsType":"not_modified","search_trims":"","features":"","total_results":3555,"model_group":"mercedes_benz-c_all","search_results_on_page":21,"search_features":"","search_make_model_groups":"","make":"","search_max_price":"","dealerSearchType":"multiple_dealers","search_min_price":null,"sort_order":"desc","search_fuel_types":"","stock_sub":"","search_drivetrains":"","transmission":"","search_seller_types":"","searchCategory":"results","search_contactless_services":"","cpo_indicator":true,"vehicleArray":[{"badges":["great_deal","virtual_appt","price_drop_in_cents","home_delivery","cpo"],"bodystyle":"Sedan","canonical_mmt":"Mercedes-Benz:C-Class:C 300 4MATIC","cat":"luxurypassenger_standard","certified_preowned":true,"cpo_indicator":true,"customer_id":"17466","exterior_color":"Lunar Blue Metallic","fuel_type":"Gasoline","listing_id":"3074b11f-71ed-4c77-8982-7a96656a3ecb","make":"Mercedes-Benz","mileage":"6396","model":"C-Class","msrp":"49105","nvi_program":false,"price":"41580","seller_type":"dealership","sponsored":true,"sponsored_type":"inventory_ad","stock_sub":"","stock_type":"Used","trim":"C 300 4MATIC","vin":"W1KWF8EB5MR633280","year":"2021"},{"badges":["fair_deal","virtual_appt","price_drop_in_cents","home_delivery","cpo"],"bodystyle":"Hatchback","canonical_mmt":"Mercedes-Benz:AMG GT 63:S 4-Door","cat":"luxurypassenger_standard","certified_preowned":true,"cpo_indicator":true,"customer_id":"102491","exterior_color":"Obsidian Black Metallic","fuel_type":"Gasoline","listing_id":"d7863a8d-1ec8-438b-b02f-235686968869","make":"Mercedes-Benz","mileage":"5625","model":"AMG GT 63","msrp":null,"nvi_program":false,"price":"165990","seller_type":"dealership","sponsored":true,"sponsored_type":"none","stock_sub":"","stock_type":"Used","trim":"S 4-Door","vin":"WDD7X8KB1LA015151","year":"2020"},{"badges":["great_deal","virtual_appt","price_drop_in_cents","home_delivery","cpo"],"bodystyle":"SUV","canonical_mmt":"Mercedes-Benz:GLB 250:Base 4MATIC","cat":"luxurysuv_crossover","certified_preowned":true,"cpo_indicator":true,"customer_id":"158182","exterior_color":"Galaxy Blue Metallic","fuel_type":"Gasoline","listing_id":"4540bad8-c263-4ffa-a6ca-ca75bd78c6fd","make":"Mercedes-Benz","mileage":"4481","model":"GLB 250","msrp":"44995","nvi_program":false,"price":"38989","seller_type":"dealership","sponsored":true,"sponsored_type":"none","stock_sub":"","stock_type":"Used","trim":"Base 4MATIC","vin":"W1N4M4HB2MW156894","year":"2021"},{"badges":["good_deal","home_delivery","cpo"],"bodystyle":"SUV","canonical_mmt":"Mercedes-Benz:GLS 450:4MATIC","cat":"luxurysuv_crossover","certified_preowned":true,"cpo_indicator":true,"customer_id":"26708","exterior_color":"Polar White","fuel_type":"Gasoline","listing_id":"405556dc-53eb-4d3e-b8fc-fa73e1b4837f","make":"Mercedes-Benz","mileage":"4256","model":"GLS 450","msrp":"107990","nvi_program":false,"price":"89989","seller_type":"dealership","sponsored":true,"sponsored_type":"none","stock_sub":"","stock_type":"Used","trim":"4MATIC","vin":"4JGFF5KE4NA640837","year":"2022"},{"badges":["good_deal","virtual_appt","price_drop_in_cents","home_delivery","cpo"],"bodystyle":"SUV","canonical_mmt":"Mercedes-Benz:GLA 250:Base","cat":"luxurysuv_crossover","certified_preowned":true,"cpo_indicator":true,"customer_id":"1212","exterior_color":"Polar White","fuel_type":"Gasoline","listing_id":"1a6882fd-820c-4508-b2a0-253258f9baf8","make":"Mercedes-Benz","mileage":"28475","model":"GLA 250","msrp":null,"nvi_program":false,"price":"31896","seller_type":"dealership","sponsored":true,"sponsored_type":"none","stock_sub":"","stock_type":"Used","trim":"Base","vin":"WDCTG4EB6LU028712","year":"2020"},{"badges":["good_deal","virtual_appt","home_delivery","cpo"],"bodys ...
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","name":"2020 Mercedes-Benz AMG GT 63 S 4-Door","position":1,"url":"https://www.cars.com/vehicledetail/d7863a8d-1ec8-438b-b02f-235686968869//"},{"@type":"ListItem","name":"2021 Mercedes-Benz GLB 250 Base 4MATIC","position":2,"url":"https://www.cars.com/vehicledetail/4540bad8-c263-4ffa-a6ca-ca75bd78c6fd//"},{"@type":"ListItem","name":"2022 Mercedes-Benz GLS 450 4MATIC","position":3,"url":"https://www.cars.com/vehicledetail/405556dc-53eb-4d3e-b8fc-fa73e1b4837f//"},{"@type":"ListItem","name":"2020 Mercedes-Benz GLA 250 Base","position":4,"url":"https://www.cars.com/vehicledetail/1a6882fd-820c-4508-b2a0-253258f9baf8//"},{"@type":"ListItem","name":"2018 Mercedes-Benz SLC 300 Base","position":5,"url":"https://www.cars.com/vehicledetail/2ca3348b-fb54-47a9-9493-a0e9b0287527//"},{"@type":"ListItem","name":"2022 Mercedes-Benz GLC 300 Base 4MATIC","position":6,"url":"https://www.cars.com/vehicledetail/b7cc0a53-859e-437f-a9b8-1c89da6a5dda//"},{"@type":"ListItem","name":"2022 Mercedes-Benz GLC 300 Base 4MATIC","position":7,"url":"https://www.cars.com/vehicledetail/3fe7bdb8-4877-4ab0-b3b5-62de7807ebee//"},{"@type":"ListItem","name":"2019 Mercedes-Benz AMG G 63 Base","position":8,"url":"https://www.cars.com/vehicledetail/2849cc6d-21f8-4cf9-bee5-ce159c9c8312//"},{"@type":"ListItem","name":"2017 Mercedes-Benz GLS 450 Base 4MATIC","position":9,"url":"https://www.cars.com/vehicledetail/f4e332d5-0de5-4132-adf9-6b2af5ea8beb//"},{"@type":"ListItem","name":"2018 Mercedes-Benz C-Class C 300 4MATIC","position":10,"url":"https://www.cars.com/vehicledetail/24edc2e6-97e6-42d3-8e20-33ddef56b0c3//"},{"@type":"ListItem","name":"2020 Mercedes-Benz GLA 250 Base","position":11,"url":"https://www.cars.com/vehicledetail/be5c8e32-d2f4-4064-b52c-2bb3280744ee//"},{"@type":"ListItem","name":"2019 Mercedes-Benz C-Class C 300","position":12,"url":"https://www.cars.com/vehicledetail/f44766d8-02ad-47ca-93c4-713a13c66535//"},{"@type":"ListItem","name":"2020 Mercedes-Benz GLB 250 Base","position":13,"url":"https://www.cars.com/vehicledetail/ab394bd6-fd16-44f2-855a-54a7467ac52f//"},{"@type":"ListItem","name":"2020 Mercedes-Benz AMG E 63 S 4MATIC","position":14,"url":"https://www.cars.com/vehicledetail/51ec1699-d295-49ad-8299-03b4609e0565//"},{"@type":"ListItem","name":"2019 Mercedes-Benz GLC 300 Base","position":15,"url":"https://www.cars.com/vehicledetail/afb4e339-8e37-46f7-a44d-00e27e81caf4//"},{"@type":"ListItem","name":"2021 Mercedes-Benz AMG GLB 35 Base","position":16,"url":"https://www.cars.com/vehicledetail/36cc1f40-2956-483a-a7cc-e70d04b4a43b//"},{"@type":"ListItem","name":"2021 Mercedes-Benz GLB 250 Base 4MATIC","position":17,"url":"https://www.cars.com/vehicledetail/6342119b-cbec-4f5a-94c2-cb76d1486a33//"},{"@type":"ListItem","name":"2021 Mercedes-Benz S-Class S 580 4MATIC","position":18,"url":"https://www.cars.com/vehicledetail/528823e5-ed4f-4693-9143-82b52386af56//"},{"@type":"ListItem","name":"2019 Mercedes-Benz C-Class C 300 4MATIC","position":19,"url":"https://www.cars.com/vehicledetail/df6af3fb-fdd1-452a-9902-1e2c27baa1e9//"},{"@type":"ListItem","name":"2019 Mercedes-Benz GLC 300 Base 4MATIC","position":20,"url":"https://www.cars.com/vehicledetail/b601e0a4-02ff-45ab-acef-d08f68f67ec5//"}],"itemListOrder":"https://schema.org/ItemListUnordered","numberOfItems":20}</script>
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"Obsidian Black Metallic","description":"Used 2020 Mercedes-Benz AMG GT 63 for sale for $165,990.","driveWheelConfiguration":"All-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/335cd571-b656-52eb-9fb9-770f071eda1c/07bab01d-a261-4e92-b48d-2f182a03847a/Ju00MomsAa-i1PnU281A9Z8BVKg.jpg"},"itemCondition":"https://schema.org/UsedCondition","mileageFromOdometer":"5625","name":"Used 2020 Mercedes-Benz AMG GT 63","sku":"LA015151","vehicleIdentificationNumber":"WDD7X8KB1LA015151","vehicleTransmission":"9-Speed Automatic"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"Galaxy Blue Metallic","description":"Used 2021 Mercedes-Benz GLB 250 for sale for $38,989.","driveWheelConfiguration":"All-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/e6b30530-040b-5ed8-9485-21b0c5dd0277/b66b37f0-2ee0-4b45-87b5-6bbb1afaab1c/2c5m6RR3wRumxdrwGz3YpTy0b34.jpg"},"itemCondition":"https://schema.org/UsedCondition","mileageFromOdometer":"4481","name":"Used 2021 Mercedes-Benz GLB 250","sku":"MW156894L","vehicleIdentificationNumber":"W1N4M4HB2MW156894","vehicleInteriorColor":"Black","vehicleTransmission":"8-Speed Automatic with Auto-Shift"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"Polar White","description":"Used 2022 Mercedes-Benz GLS 450 for sale for $89,989.","driveWheelConfiguration":"All-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/9d2f7a6f-74bd-5c49-a9ee-b160e3532da3/3f5456c5-6e42-4aa2-9f60-3000de043481/_q9X8WjeuDErha0FPcfkJFZiXdk.jpg"},"itemCondition":"https://schema.org/UsedCondition","mileageFromOdometer":"4256","name":"Used 2022 Mercedes-Benz GLS 450","sku":"M8128A","vehicleIdentificationNumber":"4JGFF5KE4NA640837","vehicleInteriorColor":"Black","vehicleTransmission":"9-Speed Automatic"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"Polar White","description":"Used 2020 Mercedes-Benz GLA 250 for sale for $31,896.","driveWheelConfiguration":"Front-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/54a75302-6b3b-5eec-9797-921c5c64cd0f/0a9e4272-5927-4168-add7-ab180c68c5bd/h-kGJbXJprAn-UrQz3YD7TVLpPY.jpg"},"itemCondition":"https://schema.org/UsedCondition","mileageFromOdometer":"28475","name":"Used 2020 Mercedes-Benz GLA 250","sku":"LU028712","vehicleIdentificationNumber":"WDCTG4EB6LU028712","vehicleTransmission":"7-Speed Automatic with Auto-Shift"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Mercedes-Benz"},"color":"Black","description":"Used 2018 Mercedes-Benz SLC 300 for sale for $50,522.","driveWheelConfiguration":"Rear-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/290738d0-9543-5faf-ac05-7538f264631b/3e030d10-7fd9-4898-8d14-b266b211bb22/XsIioPhB4x5EPTwp_H-r3S_PUtM.jpg"},"itemCondition":"https://schema.org/UsedCondition","mileageFromOdometer":"20072","name":"Used 2018 Mercedes-Benz SLC 300","sku":"P147029","vehicleIdentificationNumber":"WDDPK3JA3JF147029","vehicleInteriorColor":"Bengal Red","vehicleTransmission":"9-Speed Automatic"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availabili ...
# <nav class="search-filter-bar">
# <button class="subscribe-with-save-status-indicator" data-activity-rule-type="custom" data-component="save-search-add" data-linkname="save-search-email-modal-open" id="search_filter_bar_save_search_button" phx-click="save_search" phx-target="#search_filter_bar_save_search_button">
# <ep-svg class="save-status-indicator unsaved" name="heart-empty">
# </ep-svg>
# <span>Save search</span>
# </button>
# <button phx-click="show_sort_overlay">
# Sort
#     </button>
# <button id="show-search-form-overlay" phx-click="show_search_form_overlay">
# Filter
#     </button>
# </nav>
# <section class="sds-page-section search-live" id="search-live-container">
# <div class="display-ad" data-ad-sizes="[[970, 90], [728, 90], [970, 250], [320, 50]]" data-ad-type="full-page-width" data-ad-unit-path="6427/shop/cpo.srp/top" data-appnexus-placement-id="17848498" data-hidden-on="" id="srp-top" phx-update="ignore">
# <div alt="Advertisement" id="phx-ignore-container-srp-top" phx-update="ignore"></div>
# </div>
# </section>
# <header class="sds-page-section__header">
# <nav aria-label="breadcrumb">
# <ul class="sds-breadcrumb sds-breadcrumb--mobile-custom">
# <li class="sds-breadcrumb__parent">
# <span class="sds-icon">
# <svg aria-describedby="description" aria-labelledby="title" fill="none" height="16" role="img" stroke="#000000" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg">
# <title id="title">arrow-left</title>
# <desc id="description">An arrow pointing left.</desc>
# <path d="M19 12H6M12 5l-7 7 7 7"></path></svg>
# </span>
# <span><a data-component="breadcrumb" data-linkname="Home" href="/">Home</a></span>
# </li>
# <li aria-current="page">Cars for Sale</li>
# </ul>
# </nav>
# <script type="application/ld+json">
#   {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","item":{"@id":"https://www.cars.com/","name":"Home"},"position":1},{"@type":"ListItem","item":{"@id":"https://www.cars.com/shopping/","name":"Cars for Sale"},"position":2}]}
# </script>
# <div class="heading-container">
# ...
# <li><a aria-describedby="new-tab-link" aria-label="Dealer Login, External link" class="sds-link--ext" data-activity-rule-type="custom" data-linkname="footer-dealer-login" href="https://dealerdash.cars.com/" rel="noopener" target="_blank">Dealer Login<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# </ul>
# </div>
# </div>
# <div class="accordion-group">
# <div aria-controls="footer-section-3" aria-expanded="false" class="accordion-header" id="footer-header-3" role="button" tabindex="0">
# <span class="global-footer-heading accordion-section-title">Explore Our Brand</span>
# <svg class="accordion-section-icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# <div aria-labelledby="footer-header-3" class="accordion-panel" hidden="" id="footer-section-3" role="region">
# <ul class="global-footer-list sds-list">
# <li><a aria-describedby="new-tab-link" aria-label="Dealer Inspire, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="1" data-linkname="footer-dealer-inspire" href="https://www.dealerinspire.com/" rel="noopener" target="_blank">Dealer Inspire<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="DealerRater, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="2" data-linkname="footer-dealerrater" href="https://www.dealerrater.com/" rel="noopener" target="_blank">DealerRater<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="FUEL, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="3" data-linkname="footer-fuel" href="https://fuel.cars" rel="noopener" target="_blank">FUEL<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Auto.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="4" data-linkname="footer-autocom" href="https://www.auto.com/" rel="noopener" target="_blank">Auto.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="NewCars.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="5" data-linkname="footer-newcarscom" href="https://www.newcars.com/" rel="noopener" target="_blank">NewCars.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Pickuptrucks.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="6" data-linkname="footer-pickuptruckscom" href="https://www.pickuptrucks.com/" rel="noopener" target="_blank">Pickuptrucks.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-footer-group accordion-group">
# <div aria-controls="footer-section-4" aria-expanded="false" class="accordion-header" id="footer-header-4" role="button" tabindex="0">
# <span class="global-footer-heading accordion-section-title">Our Company</span>
# <svg class="accordion-section-icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# <div aria-labelledby="footer-header-4" class="accordion-panel" hidden="" id="footer-section-4" role="region">
# <ul class="global-footer-list sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="1" data-linkname="footer-about-cars" href="/about/">About Cars.com</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="2" data-linkname="footer-contact-cars" href="/contact/">Contact Cars.com</a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Investor Relations, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="3" data-linkname="footer-investor-relations" href="https://investor.cars.com/overview/default.aspx" rel="noopener" target="_blank">Investor Relations<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="4" data-linkname="footer-careers" href="/careers/">Careers</a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Licensing &amp; Reprints, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="5" data-linkname="footer-licensing-reprints" href="https://info.wrightsmedia.com/cars-licensing-reprints" rel="noopener" target="_blank">Licensing &amp; Reprints<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="6" data-linkname="footer-site-map" href="/sitemap/">Site Map</a></li>
# <li><a data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="7" data-linkname="footer-feedback" data-target="#qualtrics-modal" data-toggle="modal" href="#">Feedback</a></li>
# </ul>
# </div>
# </div>
# <div class="global-footer-group global-footer-apps-and-social">
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Our Mobile App</span>
# </div>
# <div class="global-footer-mobile-apps">
# <a data-activity-rule-type="page-over-page" data-linkname="footer-mobile-apps" href="/mobile/">Download the App Today</a>
# <div class="global-footer-mobile-buttons">
# <a data-activity-rule-type="custom" data-linkname="footer-app-store" href="https://apps.apple.com/us/app/cars-com-new-used-cars/id353263352">
# <img alt="App Store download" class="app-store-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/app-store-badge-us-black-1.png"/>
# </a>
# <a data-activity-rule-type="custom" data-linkname="footer-google-play" href="https://play.google.com/store/apps/details?id=com.cars.android&amp;hl=en_US">
# <img alt="Google Play download" class="google-play-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/google-play-badge-us-1.png"/>
# </a>
# </div>
# </div>
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Connect With Us</span>
# </div>
# <div class="global-footer-social-buttons">
# <ul class="global-footer-list sds-list">
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Twitter, External link" class="sds-link--ext sds-button--icon sds-icon--contain twitter" data-activity-rule-type="custom" data-component="footer-social" data-component-index="1" data-linkname="footer-twitter" href="https://twitter.com/carsdotcom" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#twitter"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Facebook, External link" class="sds-link--ext sds-button--icon sds-icon--contain facebook" data-activity-rule-type="custom" data-component="footer-social" data-component-index="2" data-linkname="footer-facebook" href="https://www.facebook.com/CarsDotCom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#facebook"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Youtube, External link" class="sds-link--ext sds-button--icon sds-icon--contain youtube" data-activity-rule-type="custom" data-component="footer-social" data-component-index="3" data-linkname="footer-youtube" href="https://www.youtube.com/user/Carscom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#youtube"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Instagram, External link" class="sds-link--ext sds-button--icon sds-icon--contain instagram" data-activity-rule-type="custom" data-component="footer-social" data-component-index="4" data-linkname="footer-instagram" href="https://www.instagram.com/carsdotcom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#instagram"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Linkedin, External link" class="sds-link--ext sds-button--icon sds-icon--contain linkedin" data-activity-rule-type="custom" data-component="footer-social" data-component-index="5" data-linkname="footer-linkedin" href="https://www.linkedin.com/company/cars-com" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#linkedin"></use></svg></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-copyright">
# <div class="sds-container">
# <ul class="sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="1" data-linkname="footer-tos" href="/about/terms/">Terms of Service</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="2" data-linkname="footer-privacy-statement" href="/about/privacy/">Privacy Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="3" data-linkname="footer-personal-information" href="/about/ccpa-privacy-notice/">Do Not Sell My Personal Information</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="4" data-linkname="footer-accessibility" href="/about/accessibility/">Accessibility Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="5" data-linkname="footer-ad-choices" href="/about/ad-choices/">Ad Choices</a></li>
# </ul>
# <div class="global-copyright-copy">©
# 2022 Cars.com. All rights reserved.</div>
# </div>
# </div>
# <div aria-modal="true" class="sds-modal sds-modal-one" id="qualtrics-modal">
# <div class="sds-modal__content">
# <div class="sds-modal__content-head sds-modal__content-head">
# <div class="sds-icon--target btn-close js-close" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <iframe class="qualtrics-form" data-src="https://cars.qualtrics.com/jfe/form/SV_81Hx3Jkheo8zhmC " height="800px" width="600px"></iframe>
# </div>
# </div>
# </footer>
# <script src=""></script>
# <link data-href="/e2aa3c3fdde1c44fd867/css/common.css?vsn=d" media="print" rel="stylesheet">
# <link data-href="/e2aa3c3fdde1c44fd867/css/srp.css?vsn=d" media="print" rel="stylesheet"/>
# <link data-href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialActivity"] = {"aff_code":"national","cat":null,"customer_id":"","designated_market_area_key":null,"lat_long":"/","local_zone":null,"loginStatus":false,"make":"","market_name":null,"marketing_click_data":null,"marketing_click_id":"","marketing_referral_source":"","model":"","page_channel":"shopping","page_detail":null,"page_key":"search-results","page_name":"shopping/search-results","page_type":"shopping/search-results","platform_id":"cars_responsive","profileAccountType":null,"seller_id":null,"trip_id":"","url_base":"","url_referer":"","useragent":"","utm_campaign":null,"utm_content":null,"utm_medium":null,"utm_source":null,"utm_term":null,"year":"","zip_ip2geo":null}
# </script>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialAls"] = {"finance_application_id":null,"als_private_data":"QTEyOEdDTQ.1M6ibQ744GApKhJKnf264dQ6NmoI5rNeZGf_lw1I6cJJRj2VG_Du3toe7yQ.xW0Daqf6PYfJbpr_.HGdPMldrO1w3ySfRMF1wzBFVnnrM9ODIo4k_K7uzNi1jgTcJ8OE0WxU6LRstbyPjywU.BeaWvXCiCd-OFwdx51MuZw","upsells":[],"results_page_number":1,"useragent":"python-requests/2.27.1","total_results":3555,"msrp":"","experiment_ids":[{"index":0,"name":"ab_test_2_srp_hp_prod"}],"vertical_position":"","utm_medium":null,"device_type":"desktop","make":"","incentive_ids":"","longitude":null,"aff_code":"national","trim":"","utm_source":null,"iframe_location":"","device_os":null,"trip_id":"","marketing_click_id":"","cpo_indicator":true,"carrier":null,"facebook_event_intent_id":"capi_viv_event","listing_id":"","customer_id":"","seller_id":null,"x_forwarded_for":null,"internet_connection":null,"profile_user_id":null,"referer_url":"","search_zipcode":"","device_id":null,"page_instance_id":"FxpHvRkohOIXpZ4FUgpi","utm_term":null,"price":null,"web_page_type_to":"shopping/search-results","latitude":null,"adobe_id":null,"ga_client_id":null,"web_page_type_from":"","results_per_page":20,"external_uuids":null,"is_bot":true,"utm_content":null,"pdid":null,"page_url":"https://www.cars.com/shopping/results/?stock_type=cpo&amp;makes[]=mercedes_benz&amp;models[]&amp;list_price_max&amp;maximum_distance=all&amp;zip","utm_campaign":null,"horizontal_position":"","platform_id":"cars_responsive","bodystyle":"","lead_event_id":null,"roxanne_visit_id":"","bot_type":"Unknown Bot (python-reque_B0B1CB20BEBCAE0F191F2D67CC6B7C5E):monitor:Behavior Anomaly;HTTP Libraries:100:aggressive","roxanne_visitor_id":"","stock_type":"","marketing_click_source":"","model":"","search_instance_id":null,"results_page_count":178,"app_version":null,"model_year":"","device_model":null,"timestamp_utc":1664721890195}
# </script>
# <script async="" data-src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   window.pbjs = window.pbjs || {que: []};
#   window.CARS = window.CARS || {};
#   window.CARS.disableAds = false;
#   window.CARS.disablePrebid = true;
#   window.CARS.isTest = false
# </script>
# <script async="" data-src="https://assets.adobedtm.com/306a737f2df1/a3d882c1ebd5/launch-3edaffcf6794.min.js"></script>
# <script async="" data-src="https://d1n00d49gkbray.cloudfront.net/js/cars.js"></script>
# <script async="" data-src="https://accounts.google.com/gsi/client" defer=""></script>
# <script>
#   window.CARS["dispatcher"] = [];
#   window.CARS["dispatcher"].push({"CarsWeb": null})
#
#
# </script>
# <script id="graphql-config" type="application/json">
#     {
#
#       "apiKey": "5rrmnWVl1MDzPcEnDvEp3Pu101IGXEGo",
#       "url": "https://graph.cars.com/graphql/api"
#     }
#   </script>
# <script src="/8R6R_hwGXQVCeR6qxA/iQ1QrXhzuQ9G/fQUZPAE/CBwLU/zQKMWIB" type="text/javascript"></script></link></body>
# </html>

# %% [markdown]
# ## Results

# %%
results = soup.find_all('div' , {'class': 'vehicle-card'})

# %%
len(results)
# Out:
# 21

# %%
results[0]
# Out:
# <div class="vehicle-card inventory-ad" data-inventory-ad="true" data-koddi-click-tracking-url="https://cars.koddi.io/event-collection/beacon?action=click&amp;trackingData={trackingData}&amp;rank={rank}&amp;clientName=Cars&amp;beaconIssued=2022-10-02T14:44:49Z" data-koddi-impression-tracking-url="https://cars.koddi.io/event-collection/beacon?action=impression&amp;trackingData={trackingData}&amp;rank={rank}&amp;ts={ts}&amp;clientName=Cars&amp;beaconIssued=2022-10-02T14:44:49Z" data-koddi-listing-id="3074b11f-71ed-4c77-8982-7a96656a3ecb" data-koddi-tracking-data="..." data-koddi-tracking-guid="a95b66c3-1932-403e-a83e-1b38c70aca10" data-koddi-user-guid="" data-listing-id="3074b11f-71ed-4c77-8982-7a96656a3ecb" data-tracking-id="1" data-tracking-type="srp-vehicle-card" id="vehicle-card-3074b11f-71ed-4c77-8982-7a96656a3ecb-sponsored" phx-hook="VehicleCard" phx-target="6">
# <a class="vehicle-card-visited-tracking-link" href="/vehicledetail/3074b11f-71ed-4c77-8982-7a96656a3ecb/" rel="nofollow" tabindex="-1"></a>
# <div class="inventory-ad-main vehicle-card-main">
# <div class="vehicle-card-photos">
# <a class="image-gallery-link" data-activity-rule-type="page-over-page" data-linkname="inventory-ad-photo" data-override-payload='{"sponsored_type":"inventory_ad","vertical_position":1,"web_page_type_from":"inventory-ad-photo"}' href="/vehicledetail/3074b11f-71ed-4c77-8982-7a96656a3ecb/" rel="nofollow"></a>
# <cars-filmstrip totalcount="26">
# <div class="gallery-wrap">
# <div aria-label="Photo 1 of 26 of 2021 Mercedes-Benz C-Class C 300 4MATIC" class="image-wrap" data-index="0">
# <img alt="Photo 1 of 26 of 2021 Mercedes-Benz C-Class C 300 4MATIC" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/bf0fc2f2-1f67-52a0-8c51-a3fb7e05273a/36f4b5fa-9f94-42f6-a614-294e03fe0fbe/rA7Twsz4k4bPjOX42iGZmTRJiDU.jpg"/>
# </div>
# <div aria-label="Photo 2 of 26 of 2021 Mercedes-Benz C-Class C 300 4MATIC" class="image-wrap" data-index="1">
# <img alt="Photo 2 of 26 of 2021 Mercedes-Benz C-Class C 300 4MATIC" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/bf0fc2f2-1f67-52a0-8c51-a3fb7e05273a/36f4b5fa-9f94-42f6-a614-294e03fe0fbe/fkaLJaRc_T8gc2c2aPAS_mHVU7c.jpg" src="/images/placeholder_10x10.png"/>
# </div>
# <div aria-label="Photo 3 of 26 of 2021 Mercedes-Benz C-Class C 300 4MATIC" class="image-wrap" data-index="2">
# <img alt="Photo 3 of 26 of 2021 Mercedes-Benz C-Class C 300 4MATIC" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/bf0fc2f2-1f67-52a0-8c51-a3fb7e05273a/36f4b5fa-9f94-42f6-a614-294e03fe0fbe/IvJtzUX4ttCIbYBnhp--eiXGQX4.jpg" src="/images/placeholder_10x10.png"/>
# </div>
# <div aria-label="Photo 4 of 26 of 2021 Mercedes-Benz C-Class C 300 4MATIC" class="image-wrap" data-index="3">
# <img alt="Photo 4 of 26 of 2021 Mercedes-Benz C-Class C 300 4MATIC" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/bf0fc2f2-1f67-52a0-8c51-a3fb7e05273a/36f4b5fa-9f94-42f6-a614-294e03fe0fbe/WWsb3y3OIGtEBcyXg5xteHU2D5U.jpg" src="/images/placeholder_10x10.png"/>
# </div>
# <div aria-label="Photo 5 of 26 of 2021 Mercedes-Benz C-Class C 300 4MATIC" class="image-wrap" data-index="4">
# <img alt="Photo 5 of 26 of 2021 Mercedes-Benz C-Class C 300 4MATIC" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/bf0fc2f2-1f67-52a0-8c51-a3fb7e05273a/36f4b5fa-9f94-42f6-a614-294e03fe0fbe/5c2y3eACuFx-KnAE15W3Aaxwj4U.jpg" src="/images/placeholder_10x10.png"/>
# </div>
# <div aria-label="Photo 6 of 26 of 2021 Mercedes-Benz C-Class C 300 4MATIC" class="image-wrap" data-index="5">
# <div class="gallery-view-all">
# <img alt="" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/bf0fc2f2-1f67-52a0-8c51-a3fb7e05273a/36f4b5fa-9f94-42f6-a614-294e03fe0fbe/aJ7El6TrHfGpidOw04hctXDSsCg.jpg" src="/images/placeholder_10x10.png"/>
# <div class="sds-button sds-button--secondary-dense">View all 26 photos</div>
# </div>
# </div>
# </div>
# </cars-filmstrip>
# </div>
# <div class="vehicle-details">
# <a class="card-whitespace-link" data-activity-rule-type="page-over-page" data-linkname="inventory-ad-whitespace" data-override-payload='{"sponsored_type":"inventory_ad","vertical_position":1,"web_page_type_from":"inventory-ad-whitespace"}' href="/vehicledetail/3074b11f-71ed-4c77-8982-7a96656a3ecb/" rel="nofollow"></a>
# <div class="save-vehicle">
# <div class="favorite">
# <button class="heart" data-activity-rule-type="custom" data-component="save-vehicle-add" data-hook-heart-id="vehicle-heart-1" data-index="1" data-linkname="save-vehicle-sign-up" data-listing-id="3074b11f-71ed-4c77-8982-7a96656a3ecb" id="vehicle-heart-1" onclick="event.preventDefault()" phx-click="save_listing" phx-hook="RecordSaveListingAction" phx-target="85" phx-value-is_vdp="false" phx-value-listing_id="3074b11f-71ed-4c77-8982-7a96656a3ecb">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#heart"></use></svg>
# <span class="text">Save</span>
# </button>
# </div>
# </div>
# <p class="stock-type">Mercedes-Benz Certified</p>
# <a class="vehicle-card-link" data-activity-rule-type="page-over-page" data-linkname="inventory-ad-header" data-override-payload='{"sponsored_type":"inventory_ad","vertical_position":1,"web_page_type_from":"inventory-ad-header"}' href="/vehicledetail/3074b11f-71ed-4c77-8982-7a96656a3ecb/" rel="nofollow" target="">
# <h2 class="title">2021 Mercedes-Benz C-Class C 300 4MATIC</h2>
# </a>
# <div class="mileage">6,396 mi.</div>
# <div class="price-section price-section-vehicle-card">
# <span class="primary-price">$41,580</span>
# <span class="secondary-price price-drop">$619 price drop</span>
# </div>
# <div class="vehicle-badging" data-click-intent-id="badges-explainer" data-contents="{&quot;cpo_badge&quot;:true,&quot;home_delivery_badge&quot;:true,&quot;price_badge&quot;:{&quot;price_badge&quot;:&quot;extremely competitively&quot;,&quot;price_badge_description&quot;:&quot;This car presents a great buying opportunity, priced at $6,144 under market. Our analysis compares this car's price, features, and condition with similar 2021 C-Class.&quot;,&quot;price_badge_savings_icon_text&quot;:&quot; | $6,144 under&quot;,&quot;price_badge_text&quot;:&quot;Great&quot;,&quot;price_badge_text_lowercase&quot;:&quot;great&quot;,&quot;price_savings_text&quot;:&quot; | $6,144 under&quot;,&quot;svg_tag&quot;:&quot;&lt;svg class=\&quot;sds-text-field__icon\&quot; height=\&quot;16\&quot; width=\&quot;16\&quot;&gt;&lt;use xlink:href=\&quot;/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-thick\&quot;&gt;&lt;/use&gt;&lt;/svg&gt;&quot;},&quot;virtual_appointments_badge&quot;:true,&quot;href_to_vdp&quot;:{&quot;href_to_vdp&quot;:&quot;/vehicledetail/3074b11f-71ed-4c77-8982-7a96656a3ecb/?bodystyle=sedan&amp;cpo_indicator=true&amp;customer_id=17466&amp;intent_id=badges-explainer&amp;listing_id=3074b11f-71ed-4c77-8982-7a96656a3ecb&amp;make=mercedes_benz&amp;model=c_class&amp;model_year=2021&amp;msrp=49105&amp;price=41580&amp;sponsored%3F=true&amp;stock_type=used&amp;trim=c+300+4matic&quot;}}" data-override-payload='{"bodystyle":"sedan","cpo_indicator":true,"customer_id":"17466","horizontal_position":null,"listing_id":"3074b11f-71ed-4c77-8982-7a96656a3ecb","make":"mercedes_benz","model":"c_class","model_year":"2021","msrp":"49105","price":"41580","results_page_number":1,"sponsored?":true,"stock_type":"used","trim":"c 300 4matic","vertical_position":1,"web_page_type_from":"premier-module"}' data-target="#sds-modal" data-toggle="expanda-modal" tabindex="0">
# <div aria-label="price_badge" class="sds-badge sds-badge--icon sds-badge--great js-price-badging" data-linkname="price-badge-great">
# <div class="sds-badge__icon">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-thick"></use></svg>
# </div>
# <span class="sds-badge__label">Great Deal<span class="sds-badge--price-savings"> | $6,144 under</span></span>
# </div>
# <div class="sds-badge sds-badge--cpo">
# <span class="sds-badge__label">CPO Warrantied</span>
# </div>
# <div class="sds-badge sds-badge--home-delivery">
# <span class="sds-badge__label">Home Delivery</span>
# </div>
# <div class="sds-badge sds-badge--virtual-appointments">
# <span class="sds-badge__label">Virtual Appointments</span>
# </div>
# </div>
# <div class="vehicle-dealer">
# <div class="dealer-name">
# <strong>Sears Imported Autos</strong>
# </div>
# <div class="sds-rating">
# <span class="sds-rating__count">4.9</span>
# <div class="sds-rating__wrapper">
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# </div>
# <span class="sds-rating__link sds-button-link">(2,004 reviews)</span>
# </div>
# <div class="miles-from hidden" data-qa="miles-from-user">
#        mi. from
#     </div>
# </div>
# <div class="sds-link--ext sds-button--link inventory_ad_deeplink" data-hidden-link-target="dealer-deeplink-3074b11f-71ed-4c77-8982-7a96656a3ecb" id="hs77lslhrirdgcddgy4p66b4hnd2tqip" phx-hook="DealerDeeplinkInventoryAd" phx-target="#vehicle-card-3074b11f-71ed-4c77-8982-7a96656a3ecb-sponsored" role="link" tabindex="0">
# <span>View on dealer's site</span>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg>
# </div>
# <div class="contact-buttons" id="sponsored-3074b11f-71ed-4c77-8982-7a96656a3ecb-lead-btns">
# <a class="sds-button--secondary contact-by-phone" data-activity-rule-type="custom" data-click-intent-id="inventory-ad-dealer-phone" data-index="1" data-linkname="inventory-ad-dealer-phone" data-listing-id="3074b11f-71ed-4c77-8982-7a96656a3ecb" data-make="Mercedes-Benz" data-model="C-Class" data-override-payload='{"bodystyle":"Sedan","customer_id":"17466","external_uuids":{"koddi_fallback_id":"fd12fcee-823f-4fca-87e2-07f6f51f587e"},"listing_id":"3074b11f-71ed-4c77-8982-7a96656a3ecb","make":"Mercedes-Benz","model":"C-Class","model_year":"2021","msrp":"49105","price":"41580","stock_type":"Used","vertical_position":1}' data-phone-number="8775824172" data-trim="C 300 4MATIC" data-vim="W1KWF8EB5MR633280" data-year="2021" href="tel:+1-877-582-4172" id="dealer-phone-3074b11f-71ed-4c77-8982-7a96656a3ecb" phx-click="call_button_clicked" phx-target="#vehicle-card-3074b11f-71ed-4c77-8982-7a96656a3ecb-sponsored">Call</a>
# <button class="sds-button lead-form-modal-button" data-activity-rule-type="custom" data-click-intent-id="inventory-ad-lead-form" data-dealer-customer-id="17466" data-index="1" data-linkname="inventory-ad-lead-form" data-listing-id="3074b11f-71ed-4c77-8982-7a96656a3ecb" data-override-payload='{"bodystyle":"Sedan","customer_id":"17466","external_uuids":{"koddi_fallback_id":"fd12fcee-823f-4fca-87e2-07f6f51f587e"},"listing_id":"3074b11f-71ed-4c77-8982-7a96656a3ecb","make":"Mercedes-Benz","model":"C-Class","model_year":"2021","msrp":"49105","price":"41580","stock_type":"Used","vertical_position":1}' data-sponsored="true" data-sponsored-invariant="true" data-sponsored-type="inventory_ad" id="lead-form-email-3074b11f-71ed-4c77-8982-7a96656a3ecb-sponsored" phx-click="check_availability_click" phx-hook="ShowLeadForm" phx-target="#vehicle-card-3074b11f-71ed-4c77-8982-7a96656a3ecb-sponsored">Check availability</button>
# <button class="sds-button lead-form-modal-button--desktop srp" data-activity-rule-type="custom" data-click-intent-id="inventory-ad-lead-form" data-dealer-customer-id="17466" data-index="1" data-linkname="inventory-ad-lead-form" data-listing-id="3074b11f-71ed-4c77-8982-7a96656a3ecb" data-override-payload='{"bodystyle":"Sedan","customer_id":"17466","external_uuids":{"koddi_fallback_id":"fd12fcee-823f-4fca-87e2-07f6f51f587e"},"listing_id":"3074b11f-71ed-4c77-8982-7a96656a3ecb","make":"Mercedes-Benz","model":"C-Class","model_year":"2021","msrp":"49105","price":"41580","stock_type":"Used","vertical_position":1}' data-sponsored="true" data-sponsored-invariant="true" data-sponsored-type="inventory_ad" id="lead-form-3074b11f-71ed-4c77-8982-7a96656a3ecb-sponsored" phx-click="check_availability_click" phx-hook="ShowLeadForm" phx-target="#vehicle-card-3074b11f-71ed-4c77-8982-7a96656a3ecb-sponsored">Check availability</button>
# </div>
# </div>
# <div class="hidden" data-connection-intent-id="inventory-ad-dealer-hyperlink" data-override-payload='{"bodystyle":"Sedan","customer_id":"17466","external_uuids":{"koddi_fallback_id":"fd12fcee-823f-4fca-87e2-07f6f51f587e"},"listing_id":"3074b11f-71ed-4c77-8982-7a96656a3ecb","make":"Mercedes-Benz","model":"C-Class","model_year":"2021","msrp":"49105","price":"41580","stock_type":"Used","vertical_position":1}'>
# <a aria-describedby="new-tab-link" aria-label="View on dealer's site, External link" class="sds-link--ext" data-activity-rule-type="custom" data-linkname="inventory-ad-dealer-hyperlink" href="https://www.searsimports.com/inventory/certified-used-2021-mercedes-benz-c-class-c-300-awd-4matic-sedan-w1kwf8eb5mr633280/?ctid=&amp;lid=3074b11f-71ed-4c77-8982-7a96656a3ecb&amp;utm_campaign=inventory_ads&amp;utm_medium=cpc&amp;utm_source=cars.com" id="dealer-deeplink-3074b11f-71ed-4c77-8982-7a96656a3ecb" rel="noopener" target="_blank">View on dealer's site<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a>
# </div>
# </div>
# </div>

# %%
results[0].find('h2')
# Out:
# <h2 class="title">2021 Mercedes-Benz C-Class C 300 4MATIC</h2>

# %%
/Users/alix
